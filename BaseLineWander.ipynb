# %%
#fetching the data from MIT-BIH
# !wget -r -N -c -np https://physionet.org/files/nstdb/1.0.0/
# !wget -r -N -c -np https://physionet.org/files/mitdb/1.0.0/
# !pip install wfdb
# Out:
# Streaming output truncated to the last 5000 lines.
# --2023-06-28 05:07:03--  https://physionet.org/files/mitdb/1.0.0/223.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/223.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2023-06-28 05:07:03 (18.2 MB/s) - ‘physionet.org/files/mitdb/1.0.0/223.xws’ saved [88/88]
#
# --2023-06-28 05:07:03--  https://physionet.org/files/mitdb/1.0.0/228.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5198 (5.1K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/228.atr’
#
# physionet.org/files 100%[===================>]   5.08K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:03 (927 MB/s) - ‘physionet.org/files/mitdb/1.0.0/228.atr’ saved [5198/5198]
#
# --2023-06-28 05:07:03--  https://physionet.org/files/mitdb/1.0.0/228.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/228.dat’
#
# physionet.org/files 100%[===================>]   1.86M   729KB/s    in 2.6s
#
# 2023-06-28 05:07:06 (729 KB/s) - ‘physionet.org/files/mitdb/1.0.0/228.dat’ saved [1950000/1950000]
#
# --2023-06-28 05:07:06--  https://physionet.org/files/mitdb/1.0.0/228.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 302 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/228.hea’
#
# physionet.org/files 100%[===================>]     302  --.-KB/s    in 0s
#
# 2023-06-28 05:07:06 (67.7 MB/s) - ‘physionet.org/files/mitdb/1.0.0/228.hea’ saved [302/302]
#
# --2023-06-28 05:07:06--  https://physionet.org/files/mitdb/1.0.0/228.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/228.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2023-06-28 05:07:06 (19.4 MB/s) - ‘physionet.org/files/mitdb/1.0.0/228.xws’ saved [88/88]
#
# --2023-06-28 05:07:06--  https://physionet.org/files/mitdb/1.0.0/230.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6386 (6.2K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/230.atr’
#
# physionet.org/files 100%[===================>]   6.24K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:06 (1.28 GB/s) - ‘physionet.org/files/mitdb/1.0.0/230.atr’ saved [6386/6386]
#
# --2023-06-28 05:07:06--  https://physionet.org/files/mitdb/1.0.0/230.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/230.dat’
#
# physionet.org/files 100%[===================>]   1.86M   747KB/s    in 2.5s
#
# 2023-06-28 05:07:08 (747 KB/s) - ‘physionet.org/files/mitdb/1.0.0/230.dat’ saved [1950000/1950000]
#
# --2023-06-28 05:07:08--  https://physionet.org/files/mitdb/1.0.0/230.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 133 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/230.hea’
#
# physionet.org/files 100%[===================>]     133  --.-KB/s    in 0s
#
# 2023-06-28 05:07:09 (32.2 MB/s) - ‘physionet.org/files/mitdb/1.0.0/230.hea’ saved [133/133]
#
# --2023-06-28 05:07:09--  https://physionet.org/files/mitdb/1.0.0/230.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/230.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2023-06-28 05:07:09 (21.7 MB/s) - ‘physionet.org/files/mitdb/1.0.0/230.xws’ saved [88/88]
#
# --2023-06-28 05:07:09--  https://physionet.org/files/mitdb/1.0.0/231.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7516 (7.3K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/231.atr’
#
# physionet.org/files 100%[===================>]   7.34K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:09 (1.38 GB/s) - ‘physionet.org/files/mitdb/1.0.0/231.atr’ saved [7516/7516]
#
# --2023-06-28 05:07:09--  https://physionet.org/files/mitdb/1.0.0/231.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/231.dat’
#
# physionet.org/files 100%[===================>]   1.86M   745KB/s    in 2.6s
#
# 2023-06-28 05:07:11 (745 KB/s) - ‘physionet.org/files/mitdb/1.0.0/231.dat’ saved [1950000/1950000]
#
# --2023-06-28 05:07:11--  https://physionet.org/files/mitdb/1.0.0/231.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 333 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/231.hea’
#
# physionet.org/files 100%[===================>]     333  --.-KB/s    in 0s
#
# 2023-06-28 05:07:11 (58.2 MB/s) - ‘physionet.org/files/mitdb/1.0.0/231.hea’ saved [333/333]
#
# --2023-06-28 05:07:11--  https://physionet.org/files/mitdb/1.0.0/231.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/231.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2023-06-28 05:07:11 (19.4 MB/s) - ‘physionet.org/files/mitdb/1.0.0/231.xws’ saved [88/88]
#
# --2023-06-28 05:07:11--  https://physionet.org/files/mitdb/1.0.0/232.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3914 (3.8K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/232.atr’
#
# physionet.org/files 100%[===================>]   3.82K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:11 (657 MB/s) - ‘physionet.org/files/mitdb/1.0.0/232.atr’ saved [3914/3914]
#
# --2023-06-28 05:07:11--  https://physionet.org/files/mitdb/1.0.0/232.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/232.dat’
#
# physionet.org/files 100%[===================>]   1.86M   769KB/s    in 2.5s
#
# 2023-06-28 05:07:14 (769 KB/s) - ‘physionet.org/files/mitdb/1.0.0/232.dat’ saved [1950000/1950000]
#
# --2023-06-28 05:07:14--  https://physionet.org/files/mitdb/1.0.0/232.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 389 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/232.hea’
#
# physionet.org/files 100%[===================>]     389  --.-KB/s    in 0s
#
# 2023-06-28 05:07:14 (59.4 MB/s) - ‘physionet.org/files/mitdb/1.0.0/232.hea’ saved [389/389]
#
# --2023-06-28 05:07:14--  https://physionet.org/files/mitdb/1.0.0/232.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/232.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2023-06-28 05:07:14 (20.2 MB/s) - ‘physionet.org/files/mitdb/1.0.0/232.xws’ saved [88/88]
#
# --2023-06-28 05:07:14--  https://physionet.org/files/mitdb/1.0.0/233.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6770 (6.6K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/233.atr’
#
# physionet.org/files 100%[===================>]   6.61K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:14 (1.16 GB/s) - ‘physionet.org/files/mitdb/1.0.0/233.atr’ saved [6770/6770]
#
# --2023-06-28 05:07:14--  https://physionet.org/files/mitdb/1.0.0/233.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/233.dat’
#
# physionet.org/files 100%[===================>]   1.86M   763KB/s    in 2.5s
#
# 2023-06-28 05:07:17 (763 KB/s) - ‘physionet.org/files/mitdb/1.0.0/233.dat’ saved [1950000/1950000]
#
# --2023-06-28 05:07:17--  https://physionet.org/files/mitdb/1.0.0/233.hea
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/233.hea’
#
# physionet.org/files 100%[===================>]     162  --.-KB/s    in 0s
#
# 2023-06-28 05:07:17 (37.2 MB/s) - ‘physionet.org/files/mitdb/1.0.0/233.hea’ saved [162/162]
#
# --2023-06-28 05:07:17--  https://physionet.org/files/mitdb/1.0.0/233.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/233.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2023-06-28 05:07:17 (22.9 MB/s) - ‘physionet.org/files/mitdb/1.0.0/233.xws’ saved [88/88]
#
# --2023-06-28 05:07:17--  https://physionet.org/files/mitdb/1.0.0/234.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5560 (5.4K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/234.atr’
#
# physionet.org/files 100%[===================>]   5.43K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:17 (1.00 GB/s) - ‘physionet.org/files/mitdb/1.0.0/234.atr’ saved [5560/5560]
#
# --2023-06-28 05:07:17--  https://physionet.org/files/mitdb/1.0.0/234.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/234.dat’
#
# physionet.org/files 100%[===================>]   1.86M   755KB/s    in 2.5s
#
# 2023-06-28 05:07:20 (755 KB/s) - ‘physionet.org/files/mitdb/1.0.0/234.dat’ saved [1950000/1950000]
#
# --2023-06-28 05:07:20--  https://physionet.org/files/mitdb/1.0.0/234.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 156 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/234.hea’
#
# physionet.org/files 100%[===================>]     156  --.-KB/s    in 0s
#
# 2023-06-28 05:07:20 (39.2 MB/s) - ‘physionet.org/files/mitdb/1.0.0/234.hea’ saved [156/156]
#
# --2023-06-28 05:07:20--  https://physionet.org/files/mitdb/1.0.0/234.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/234.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2023-06-28 05:07:20 (21.4 MB/s) - ‘physionet.org/files/mitdb/1.0.0/234.xws’ saved [88/88]
#
# --2023-06-28 05:07:20--  https://physionet.org/files/mitdb/1.0.0/ANNOTATORS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/ANNOTATORS’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2023-06-28 05:07:20 (13.8 MB/s) - ‘physionet.org/files/mitdb/1.0.0/ANNOTATORS’ saved [59/59]
#
# --2023-06-28 05:07:20--  https://physionet.org/files/mitdb/1.0.0/RECORDS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 192 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/RECORDS’
#
# physionet.org/files 100%[===================>]     192  --.-KB/s    in 0s
#
# 2023-06-28 05:07:20 (43.6 MB/s) - ‘physionet.org/files/mitdb/1.0.0/RECORDS’ saved [192/192]
#
# --2023-06-28 05:07:20--  https://physionet.org/files/mitdb/1.0.0/SHA256SUMS.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60849 (59K) [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/SHA256SUMS.txt’
#
# physionet.org/files 100%[===================>]  59.42K  --.-KB/s    in 0.06s
#
# 2023-06-28 05:07:20 (984 KB/s) - ‘physionet.org/files/mitdb/1.0.0/SHA256SUMS.txt’ saved [60849/60849]
#
# --2023-06-28 05:07:20--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/src/makefile
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8921 (8.7K) [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/src/makefile’
#
# physionet.org/files 100%[===================>]   8.71K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:20 (259 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/src/makefile’ saved [8921/8921]
#
# --2023-06-28 05:07:20--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/src/printdir.bat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3437 (3.4K) [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/src/printdir.bat’
#
# physionet.org/files 100%[===================>]   3.36K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:20 (704 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/src/printdir.bat’ saved [3437/3437]
#
# --2023-06-28 05:07:20--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/foreword.htm
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7434 (7.3K) [text/html]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/foreword.htm’
#
# physionet.org/files 100%[===================>]   7.26K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:20 (1.13 GB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/foreword.htm’ saved [7434/7434]
#
# --2023-06-28 05:07:20--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/intro.htm
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 17631 (17K) [text/html]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/intro.htm’
#
# physionet.org/files 100%[===================>]  17.22K  --.-KB/s    in 0.003s
#
# 2023-06-28 05:07:20 (4.95 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/intro.htm’ saved [17631/17631]
#
# --2023-06-28 05:07:20--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/records.htm
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 100094 (98K) [text/html]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/records.htm’
#
# physionet.org/files 100%[===================>]  97.75K  --.-KB/s    in 0.1s
#
# 2023-06-28 05:07:21 (888 KB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/records.htm’ saved [100094/100094]
#
# --2023-06-28 05:07:21--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/tables.htm
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 44278 (43K) [text/html]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/tables.htm’
#
# physionet.org/files 100%[===================>]  43.24K  --.-KB/s    in 0.04s
#
# 2023-06-28 05:07:21 (1.08 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/tables.htm’ saved [44278/44278]
#
# --2023-06-28 05:07:21--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/ANNOTATORS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/ANNOTATORS’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2023-06-28 05:07:21 (12.5 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/ANNOTATORS’ saved [59/59]
#
# --2023-06-28 05:07:21--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/RECORDS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 138 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/RECORDS’
#
# physionet.org/files 100%[===================>]     138  --.-KB/s    in 0s
#
# 2023-06-28 05:07:21 (23.7 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/RECORDS’ saved [138/138]
#
# --2023-06-28 05:07:21--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_108.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1200 (1.2K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_108.atr’
#
# physionet.org/files 100%[===================>]   1.17K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:21 (261 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_108.atr’ saved [1200/1200]
#
# --2023-06-28 05:07:21--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_108.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_108.dat’
#
# physionet.org/files 100%[===================>] 632.81K   747KB/s    in 0.8s
#
# 2023-06-28 05:07:22 (747 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_108.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:22--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_108.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 373 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_108.hea’
#
# physionet.org/files 100%[===================>]     373  --.-KB/s    in 0s
#
# 2023-06-28 05:07:22 (72.2 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_108.hea’ saved [373/373]
#
# --2023-06-28 05:07:22--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_109.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1724 (1.7K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_109.atr’
#
# physionet.org/files 100%[===================>]   1.68K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:22 (355 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_109.atr’ saved [1724/1724]
#
# --2023-06-28 05:07:22--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_109.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_109.dat’
#
# physionet.org/files 100%[===================>] 632.81K   751KB/s    in 0.8s
#
# 2023-06-28 05:07:23 (751 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_109.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:23--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_109.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 263 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_109.hea’
#
# physionet.org/files 100%[===================>]     263  --.-KB/s    in 0s
#
# 2023-06-28 05:07:23 (11.8 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_109.hea’ saved [263/263]
#
# --2023-06-28 05:07:23--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_111.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1420 (1.4K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_111.atr’
#
# physionet.org/files 100%[===================>]   1.39K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:23 (331 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_111.atr’ saved [1420/1420]
#
# --2023-06-28 05:07:23--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_111.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_111.dat’
#
# physionet.org/files 100%[===================>] 632.81K   752KB/s    in 0.8s
#
# 2023-06-28 05:07:24 (752 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_111.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:24--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_111.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 351 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_111.hea’
#
# physionet.org/files 100%[===================>]     351  --.-KB/s    in 0s
#
# 2023-06-28 05:07:24 (78.7 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_111.hea’ saved [351/351]
#
# --2023-06-28 05:07:24--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_112.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1718 (1.7K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_112.atr’
#
# physionet.org/files 100%[===================>]   1.68K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:24 (360 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_112.atr’ saved [1718/1718]
#
# --2023-06-28 05:07:24--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_112.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_112.dat’
#
# physionet.org/files 100%[===================>] 632.81K   772KB/s    in 0.8s
#
# 2023-06-28 05:07:25 (772 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_112.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:25--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_112.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 265 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_112.hea’
#
# physionet.org/files 100%[===================>]     265  --.-KB/s    in 0s
#
# 2023-06-28 05:07:25 (53.7 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_112.hea’ saved [265/265]
#
# --2023-06-28 05:07:25--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_113.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1172 (1.1K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_113.atr’
#
# physionet.org/files 100%[===================>]   1.14K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:25 (257 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_113.atr’ saved [1172/1172]
#
# --2023-06-28 05:07:25--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_113.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_113.dat’
#
# physionet.org/files 100%[===================>] 632.81K   771KB/s    in 0.8s
#
# 2023-06-28 05:07:26 (771 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_113.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:26--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_113.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 300 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_113.hea’
#
# physionet.org/files 100%[===================>]     300  --.-KB/s    in 0s
#
# 2023-06-28 05:07:26 (73.7 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_113.hea’ saved [300/300]
#
# --2023-06-28 05:07:26--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_114.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1180 (1.2K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_114.atr’
#
# physionet.org/files 100%[===================>]   1.15K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:26 (286 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_114.atr’ saved [1180/1180]
#
# --2023-06-28 05:07:26--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_114.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_114.dat’
#
# physionet.org/files 100%[===================>] 632.81K   774KB/s    in 0.8s
#
# 2023-06-28 05:07:27 (774 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_114.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:27--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_114.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 225 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_114.hea’
#
# physionet.org/files 100%[===================>]     225  --.-KB/s    in 0s
#
# 2023-06-28 05:07:27 (37.6 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_114.hea’ saved [225/225]
#
# --2023-06-28 05:07:27--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_115.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1280 (1.2K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_115.atr’
#
# physionet.org/files 100%[===================>]   1.25K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:27 (250 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_115.atr’ saved [1280/1280]
#
# --2023-06-28 05:07:27--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_115.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_115.dat’
#
# physionet.org/files 100%[===================>] 632.81K   751KB/s    in 0.8s
#
# 2023-06-28 05:07:28 (751 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_115.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:28--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_115.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 194 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_115.hea’
#
# physionet.org/files 100%[===================>]     194  --.-KB/s    in 0s
#
# 2023-06-28 05:07:28 (44.0 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_115.hea’ saved [194/194]
#
# --2023-06-28 05:07:28--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_116.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1604 (1.6K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_116.atr’
#
# physionet.org/files 100%[===================>]   1.57K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:28 (373 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_116.atr’ saved [1604/1604]
#
# --2023-06-28 05:07:28--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_116.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_116.dat’
#
# physionet.org/files 100%[===================>] 632.81K   731KB/s    in 0.9s
#
# 2023-06-28 05:07:29 (731 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_116.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:29--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_116.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 224 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_116.hea’
#
# physionet.org/files 100%[===================>]     224  --.-KB/s    in 0s
#
# 2023-06-28 05:07:29 (52.3 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_116.hea’ saved [224/224]
#
# --2023-06-28 05:07:29--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_117.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1020 [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_117.atr’
#
# physionet.org/files 100%[===================>]    1020  --.-KB/s    in 0s
#
# 2023-06-28 05:07:29 (142 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_117.atr’ saved [1020/1020]
#
# --2023-06-28 05:07:29--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_117.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_117.dat’
#
# physionet.org/files 100%[===================>] 632.81K   726KB/s    in 0.9s
#
# 2023-06-28 05:07:30 (726 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_117.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:30--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_117.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 194 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_117.hea’
#
# physionet.org/files 100%[===================>]     194  --.-KB/s    in 0s
#
# 2023-06-28 05:07:30 (44.6 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_117.hea’ saved [194/194]
#
# --2023-06-28 05:07:30--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_121.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1234 (1.2K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_121.atr’
#
# physionet.org/files 100%[===================>]   1.21K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:30 (241 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_121.atr’ saved [1234/1234]
#
# --2023-06-28 05:07:30--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_121.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_121.dat’
#
# physionet.org/files 100%[===================>] 632.81K   738KB/s    in 0.9s
#
# 2023-06-28 05:07:31 (738 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_121.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:31--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_121.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 220 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_121.hea’
#
# physionet.org/files 100%[===================>]     220  --.-KB/s    in 0s
#
# 2023-06-28 05:07:31 (51.3 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_121.hea’ saved [220/220]
#
# --2023-06-28 05:07:31--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_122.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1692 (1.7K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_122.atr’
#
# physionet.org/files 100%[===================>]   1.65K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:31 (280 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_122.atr’ saved [1692/1692]
#
# --2023-06-28 05:07:31--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_122.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_122.dat’
#
# physionet.org/files 100%[===================>] 632.81K   726KB/s    in 0.9s
#
# 2023-06-28 05:07:32 (726 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_122.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:32--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_122.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 288 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_122.hea’
#
# physionet.org/files 100%[===================>]     288  --.-KB/s    in 0s
#
# 2023-06-28 05:07:32 (68.6 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_122.hea’ saved [288/288]
#
# --2023-06-28 05:07:32--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_123.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1022 [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_123.atr’
#
# physionet.org/files 100%[===================>]    1022  --.-KB/s    in 0s
#
# 2023-06-28 05:07:32 (214 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_123.atr’ saved [1022/1022]
#
# --2023-06-28 05:07:32--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_123.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_123.dat’
#
# physionet.org/files 100%[===================>] 632.81K   725KB/s    in 0.9s
#
# 2023-06-28 05:07:33 (725 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_123.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:33--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_123.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 246 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_123.hea’
#
# physionet.org/files 100%[===================>]     246  --.-KB/s    in 0s
#
# 2023-06-28 05:07:33 (58.9 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_123.hea’ saved [246/246]
#
# --2023-06-28 05:07:33--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_124.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1102 (1.1K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_124.atr’
#
# physionet.org/files 100%[===================>]   1.08K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:34 (245 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_124.atr’ saved [1102/1102]
#
# --2023-06-28 05:07:34--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_124.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_124.dat’
#
# physionet.org/files 100%[===================>] 632.81K   735KB/s    in 0.9s
#
# 2023-06-28 05:07:34 (735 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_124.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:34--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_124.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 287 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_124.hea’
#
# physionet.org/files 100%[===================>]     287  --.-KB/s    in 0s
#
# 2023-06-28 05:07:35 (13.2 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_124.hea’ saved [287/287]
#
# --2023-06-28 05:07:35--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_220.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1504 (1.5K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_220.atr’
#
# physionet.org/files 100%[===================>]   1.47K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:35 (324 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_220.atr’ saved [1504/1504]
#
# --2023-06-28 05:07:35--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_220.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_220.dat’
#
# physionet.org/files 100%[===================>] 632.81K   740KB/s    in 0.9s
#
# 2023-06-28 05:07:36 (740 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_220.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:36--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_220.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 197 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_220.hea’
#
# physionet.org/files 100%[===================>]     197  --.-KB/s    in 0s
#
# 2023-06-28 05:07:36 (43.8 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_220.hea’ saved [197/197]
#
# --2023-06-28 05:07:36--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_221.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2052 (2.0K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_221.atr’
#
# physionet.org/files 100%[===================>]   2.00K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:36 (422 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_221.atr’ saved [2052/2052]
#
# --2023-06-28 05:07:36--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_221.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_221.dat’
#
# physionet.org/files 100%[===================>] 632.81K   749KB/s    in 0.8s
#
# 2023-06-28 05:07:37 (749 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_221.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:37--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_221.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 294 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_221.hea’
#
# physionet.org/files 100%[===================>]     294  --.-KB/s    in 0s
#
# 2023-06-28 05:07:37 (61.2 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_221.hea’ saved [294/294]
#
# --2023-06-28 05:07:37--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_222.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1552 (1.5K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_222.atr’
#
# physionet.org/files 100%[===================>]   1.52K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:37 (298 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_222.atr’ saved [1552/1552]
#
# --2023-06-28 05:07:37--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_222.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_222.dat’
#
# physionet.org/files 100%[===================>] 632.81K   738KB/s    in 0.9s
#
# 2023-06-28 05:07:38 (738 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_222.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:38--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_222.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 397 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_222.hea’
#
# physionet.org/files 100%[===================>]     397  --.-KB/s    in 0s
#
# 2023-06-28 05:07:38 (66.9 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_222.hea’ saved [397/397]
#
# --2023-06-28 05:07:38--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_223.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1724 (1.7K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_223.atr’
#
# physionet.org/files 100%[===================>]   1.68K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:38 (324 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_223.atr’ saved [1724/1724]
#
# --2023-06-28 05:07:38--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_223.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_223.dat’
#
# physionet.org/files 100%[===================>] 632.81K   747KB/s    in 0.8s
#
# 2023-06-28 05:07:39 (747 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_223.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:39--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_223.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 323 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_223.hea’
#
# physionet.org/files 100%[===================>]     323  --.-KB/s    in 0s
#
# 2023-06-28 05:07:39 (82.2 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_223.hea’ saved [323/323]
#
# --2023-06-28 05:07:39--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_228.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1872 (1.8K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_228.atr’
#
# physionet.org/files 100%[===================>]   1.83K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:39 (366 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_228.atr’ saved [1872/1872]
#
# --2023-06-28 05:07:39--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_228.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_228.dat’
#
# physionet.org/files 100%[===================>] 632.81K   758KB/s    in 0.8s
#
# 2023-06-28 05:07:40 (758 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_228.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:40--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_228.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 367 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_228.hea’
#
# physionet.org/files 100%[===================>]     367  --.-KB/s    in 0s
#
# 2023-06-28 05:07:40 (92.8 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_228.hea’ saved [367/367]
#
# --2023-06-28 05:07:40--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_230.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2288 (2.2K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_230.atr’
#
# physionet.org/files 100%[===================>]   2.23K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:40 (490 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_230.atr’ saved [2288/2288]
#
# --2023-06-28 05:07:40--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_230.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_230.dat’
#
# physionet.org/files 100%[===================>] 632.81K   743KB/s    in 0.9s
#
# 2023-06-28 05:07:41 (743 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_230.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:41--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_230.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 198 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_230.hea’
#
# physionet.org/files 100%[===================>]     198  --.-KB/s    in 0s
#
# 2023-06-28 05:07:41 (43.6 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_230.hea’ saved [198/198]
#
# --2023-06-28 05:07:41--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_231.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2760 (2.7K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_231.atr’
#
# physionet.org/files 100%[===================>]   2.70K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:41 (502 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_231.atr’ saved [2760/2760]
#
# --2023-06-28 05:07:41--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_231.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_231.dat’
#
# physionet.org/files 100%[===================>] 632.81K   738KB/s    in 0.9s
#
# 2023-06-28 05:07:42 (738 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_231.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:42--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_231.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 397 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_231.hea’
#
# physionet.org/files 100%[===================>]     397  --.-KB/s    in 0s
#
# 2023-06-28 05:07:42 (84.4 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_231.hea’ saved [397/397]
#
# --2023-06-28 05:07:42--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_232.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1294 (1.3K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_232.atr’
#
# physionet.org/files 100%[===================>]   1.26K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:42 (308 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_232.atr’ saved [1294/1294]
#
# --2023-06-28 05:07:42--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_232.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_232.dat’
#
# physionet.org/files 100%[===================>] 632.81K   745KB/s    in 0.8s
#
# 2023-06-28 05:07:43 (745 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_232.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:43--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_232.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 453 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_232.hea’
#
# physionet.org/files 100%[===================>]     453  --.-KB/s    in 0s
#
# 2023-06-28 05:07:43 (114 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_232.hea’ saved [453/453]
#
# --2023-06-28 05:07:43--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_233.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2272 (2.2K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_233.atr’
#
# physionet.org/files 100%[===================>]   2.22K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:43 (465 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_233.atr’ saved [2272/2272]
#
# --2023-06-28 05:07:43--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_233.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_233.dat’
#
# physionet.org/files 100%[===================>] 632.81K   765KB/s    in 0.8s
#
# 2023-06-28 05:07:44 (765 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_233.dat’ saved [648000/648000]
#
# --2023-06-28 05:07:44--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_233.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 229 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_233.hea’
#
# physionet.org/files 100%[===================>]     229  --.-KB/s    in 0s
#
# 2023-06-28 05:07:44 (56.7 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_233.hea’ saved [229/229]
#
# --2023-06-28 05:07:44--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_234.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1866 (1.8K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_234.atr’
#
# physionet.org/files 100%[===================>]   1.82K  --.-KB/s    in 0s
#
# 2023-06-28 05:07:44 (403 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_234.atr’ saved [1866/1866]
#
# --2023-06-28 05:07:44--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_234.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_234.dat’
#
# physionet.org/files 100%[===================>] 632.81K   766KB/s    in 0.8s
#
# ...
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2320151.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2023-06-28 05:08:08 (19.5 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2320151.xws’ saved [91/91]
#
# --2023-06-28 05:08:08--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2321151.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 92 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2321151.xws’
#
# physionet.org/files 100%[===================>]      92  --.-KB/s    in 0s
#
# 2023-06-28 05:08:08 (18.0 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2321151.xws’ saved [92/92]
#
# --2023-06-28 05:08:08--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2321306.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 92 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2321306.xws’
#
# physionet.org/files 100%[===================>]      92  --.-KB/s    in 0s
#
# 2023-06-28 05:08:08 (19.1 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2321306.xws’ saved [92/92]
#
# --2023-06-28 05:08:08--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2321509.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 92 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2321509.xws’
#
# physionet.org/files 100%[===================>]      92  --.-KB/s    in 0s
#
# 2023-06-28 05:08:08 (20.2 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2321509.xws’ saved [92/92]
#
# --2023-06-28 05:08:08--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2321817.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 92 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2321817.xws’
#
# physionet.org/files 100%[===================>]      92  --.-KB/s    in 0s
#
# 2023-06-28 05:08:08 (22.4 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2321817.xws’ saved [92/92]
#
# --2023-06-28 05:08:08--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2322231.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 92 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2322231.xws’
#
# physionet.org/files 100%[===================>]      92  --.-KB/s    in 0s
#
# 2023-06-28 05:08:08 (19.9 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2322231.xws’ saved [92/92]
#
# --2023-06-28 05:08:08--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2322247.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 92 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2322247.xws’
#
# physionet.org/files 100%[===================>]      92  --.-KB/s    in 0s
#
# 2023-06-28 05:08:09 (20.4 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2322247.xws’ saved [92/92]
#
# --2023-06-28 05:08:09--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2322320.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 92 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2322320.xws’
#
# physionet.org/files 100%[===================>]      92  --.-KB/s    in 0s
#
# 2023-06-28 05:08:09 (18.3 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2322320.xws’ saved [92/92]
#
# --2023-06-28 05:08:09--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2322334.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 92 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2322334.xws’
#
# physionet.org/files 100%[===================>]      92  --.-KB/s    in 0s
#
# 2023-06-28 05:08:09 (15.9 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2322334.xws’ saved [92/92]
#
# --2023-06-28 05:08:09--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2322353.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 92 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2322353.xws’
#
# physionet.org/files 100%[===================>]      92  --.-KB/s    in 0s
#
# 2023-06-28 05:08:09 (24.6 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2322353.xws’ saved [92/92]
#
# --2023-06-28 05:08:09--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2330011.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2330011.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2023-06-28 05:08:09 (18.3 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2330011.xws’ saved [91/91]
#
# --2023-06-28 05:08:09--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2330025.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2330025.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2023-06-28 05:08:09 (16.9 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2330025.xws’ saved [91/91]
#
# --2023-06-28 05:08:09--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2330218.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2330218.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2023-06-28 05:08:09 (16.9 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2330218.xws’ saved [91/91]
#
# --2023-06-28 05:08:09--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2330243.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2330243.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2023-06-28 05:08:09 (18.4 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2330243.xws’ saved [91/91]
#
# --2023-06-28 05:08:09--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2330339.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2330339.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2023-06-28 05:08:09 (24.9 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2330339.xws’ saved [91/91]
#
# --2023-06-28 05:08:09--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2330502.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2330502.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2023-06-28 05:08:09 (18.9 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2330502.xws’ saved [91/91]
#
# --2023-06-28 05:08:09--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2330943.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2330943.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2023-06-28 05:08:09 (23.3 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2330943.xws’ saved [91/91]
#
# --2023-06-28 05:08:09--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2331620.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 92 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2331620.xws’
#
# physionet.org/files 100%[===================>]      92  --.-KB/s    in 0s
#
# 2023-06-28 05:08:09 (18.5 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2331620.xws’ saved [92/92]
#
# --2023-06-28 05:08:09--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2331802.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 92 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2331802.xws’
#
# physionet.org/files 100%[===================>]      92  --.-KB/s    in 0s
#
# 2023-06-28 05:08:09 (21.0 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2331802.xws’ saved [92/92]
#
# --2023-06-28 05:08:09--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2332223.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 92 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2332223.xws’
#
# physionet.org/files 100%[===================>]      92  --.-KB/s    in 0s
#
# 2023-06-28 05:08:09 (16.8 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2332223.xws’ saved [92/92]
#
# --2023-06-28 05:08:09--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2340016.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2340016.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2023-06-28 05:08:09 (17.2 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2340016.xws’ saved [91/91]
#
# --2023-06-28 05:08:09--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2340637.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2340637.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2023-06-28 05:08:09 (16.2 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2340637.xws’ saved [91/91]
#
# --2023-06-28 05:08:09--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2341401.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 92 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2341401.xws’
#
# physionet.org/files 100%[===================>]      92  --.-KB/s    in 0s
#
# 2023-06-28 05:08:09 (20.4 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2341401.xws’ saved [92/92]
#
# --2023-06-28 05:08:09--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2341426.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 92 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2341426.xws’
#
# physionet.org/files 100%[===================>]      92  --.-KB/s    in 0s
#
# 2023-06-28 05:08:10 (22.6 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2341426.xws’ saved [92/92]
#
# --2023-06-28 05:08:10--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2341702.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 92 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2341702.xws’
#
# physionet.org/files 100%[===================>]      92  --.-KB/s    in 0s
#
# 2023-06-28 05:08:10 (16.3 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2341702.xws’ saved [92/92]
#
# --2023-06-28 05:08:10--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2342126.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 92 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2342126.xws’
#
# physionet.org/files 100%[===================>]      92  --.-KB/s    in 0s
#
# 2023-06-28 05:08:10 (19.6 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2342126.xws’ saved [92/92]
#
# --2023-06-28 05:08:10--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2342317.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 92 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2342317.xws’
#
# physionet.org/files 100%[===================>]      92  --.-KB/s    in 0s
#
# 2023-06-28 05:08:10 (17.8 MB/s) - ‘physionet.org/files/mitdb/1.0.0/mitdbdir/samples/2342317.xws’ saved [92/92]
#
# FINISHED --2023-06-28 05:08:10--
# Total wall clock time: 3m 9s
# Downloaded: 677 files, 104M in 2m 24s (741 KB/s)
# Collecting wfdb
#   Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb) (3.7.1)
# Requirement already satisfied: numpy>=1.10.1 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.22.4)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.5.3)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from wfdb) (2.27.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->wfdb) (2022.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (3.4)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb) (2.21)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.16.0)
# Installing collected packages: wfdb
# Successfully installed wfdb-4.1.2

# %%
#imports here
import wfdb
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import math
from sklearn.preprocessing import MinMaxScaler, normalize
from statistics import variance as var
from operator import add

# %%
#reading the muscle artifact noise and spliting it into 650 parts each of length 1000 and normalizing it
#bw contains 650000 sample points
bw,f = wfdb.rdsamp('/content/physionet.org/files/nstdb/1.0.0/bw', sampto=650000)
bw=np.array(bw)
noise=[]
v=0
for i in range(649):
  y=[]
  for k in range(1000):
    y.append(bw[v+k][0])
  z=[]
  p=max(y)
  q=min(y)
  for l in range(len(y)):
      t=(y[l]-q)/(p-q)
      z.append(t)
  noise.append(z)
  v=v+1000
plt.plot(noise[1])

# %%
# reading data spliting and normalizing it........
data=[]
rec=['100','101','102','103','104','105','106','107','108','109','111','112','113','114','115','116','117','118','119','121','122','123','124','200','201','202','203','205','207','208','209','210','212','213','214','215','217','219','220','221','222','223','228','230','231','232','233','234']

for string in rec:
  record= wfdb.rdsamp('/content/physionet.org/files/mitdb/1.0.0/'+string, sampto=650000)
  ann = wfdb.rdann('/content/physionet.org/files/mitdb/1.0.0/'+string, 'atr', sampto=650000)
  I = record[0][:, 0]
  a=0
  e=1000
  for i in range(650):
    z=[]
    d=I[a:e]
    p=max(d)
    q=min(d)
    for l in range(len(d)):
      t=(d[l]-q)/(p-q)
      z.append(t)
    data.append(z)
    a+=1000
    e+=1000
#plotting the acquired ecg signal, mind that we are only taking lead I
plt.plot(data[1])
plt.xlabel('samples')
plt.ylabel('mV')
#dividing data in train and test test samples
train_data=[]
test_data=[]
for i in range(int(len(data)*0.8)):
  train_data.append(data[i])
for j in range(int(len(data)*0.8),len(data)):
  test_data.append(data[j])

# %%
fig_size = plt.rcParams["figure.figsize"]

# Prints: [8.0, 6.0]
print("Current size:", fig_size)
# Set figure width to 12 and height to 9
fig_size[0] = 10
fig_size[1] = 2
plt.rcParams["figure.figsize"] = fig_size
plt.plot(data[1000])
plt.xlabel('samples')
plt.ylabel('mV')
# Out:
# Current size: [6.4, 4.8]
# Text(0, 0.5, 'mV')

# %%
#noise_bw_data base
import random
n=[]
n_tr=[]
n_ts=[]
noise_bw_data=[]
for i in range(31200):
  l=random.randrange(0,200)
  n.append(noise[l])
  p=list(map(add,data[i],noise[l]))
  p=np.array(p)
  noise_bw_data.append(p)
trainbw_data=[]
testbw_data=[]
for i in range(int(len(noise_bw_data)*0.8)):
  trainbw_data.append(noise_bw_data[i])
  n_tr.append(n[i])
for j in range(int(len(noise_bw_data)*0.8),len(noise_bw_data)):
  testbw_data.append(noise_bw_data[j])
  n_ts.append(n[j])

# %%
plt.plot(noise_bw_data[15000])

# %%
#Metrics for future implementation
#to calulate snr, rmse, max_abs_val, normalized_cross_correlation
#https://github.com/scipy/scipy/issues/9097
def urms(x):
  y=[]
  for i in range(len(x)):
    y.append(x[i]**2)
  s=sum(y)
  return s
def signaltonoise(a,b):
  a=urms(a)
  b=urms(b)
  snr=a/b
  return np.log(snr)*10
#intellipaat.com/community/1269/is-there-a-library-function-for-root-mean-square-error-rmse-in-python
def rmse(predictions, targets):
    return np.sqrt(((np.array(predictions) - np.array(targets)) ** 2).mean())
#https://stackoverflow.com/questions/44864633/pythonic-way-to-find-maximum-absolute-value-of-list
def max_abs_val(samp_list):
  max_abs_value = samp_list[0]
  for num in samp_list:
      if abs(num) > max_abs_value:
          max_abs_value = abs(num)
  return max_abs_value
#www.researchgate.net/post/How_can_one_calculate_normalized_cross_correlation_between_two_arrays
def normalized_cross_corr(x,y):
  x,y=np.array(x),np.array(y)
  N=len(x)
  a=(np.sqrt(var(x)*var(y)))
  b=(x - x.mean())* (y - y.mean())
  ncc = (1/N)*(sum(b))
  return ncc/a
def convert_numpy_tensor(arr):
  arr=np.array(arr)
  ten=torch.from_numpy(arr)
  return ten

# %%
#AutoEncoder
# define the NN architecture
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(1000,500)
        self.fc2 = nn.Linear(500,250)
        self.fc3 = nn.Linear(250,100)
        self.fc4=nn.Linear(100,250)
        self.fc5=nn.Linear(250,500)
        self.fc6=nn.Linear(500,1000)
        self.dropout = nn.Dropout(0.2)
    def encoder(self, x):
        x=x.squeeze()
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        x=F.relu(x)
        return x
    def decoder(self,x):
        x = F.relu(self.fc4(x))
        x = F.relu(self.fc5(x))
        x = self.fc6(x)
        x=x.view(-1)
        return x
# initialize the NN
model = Net()
model.cuda()
print(model)
model.double()
# Out:
# Net(
#   (fc1): Linear(in_features=1000, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=250, bias=True)
#   (fc3): Linear(in_features=250, out_features=100, bias=True)
#   (fc4): Linear(in_features=100, out_features=250, bias=True)
#   (fc5): Linear(in_features=250, out_features=500, bias=True)
#   (fc6): Linear(in_features=500, out_features=1000, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )
# Net(
#   (fc1): Linear(in_features=1000, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=250, bias=True)
#   (fc3): Linear(in_features=250, out_features=100, bias=True)
#   (fc4): Linear(in_features=100, out_features=250, bias=True)
#   (fc5): Linear(in_features=250, out_features=500, bias=True)
#   (fc6): Linear(in_features=500, out_features=1000, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
# specify loss function
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.09,momentum=0.2)
# number of epochs to train the model
n_epochs = 100
# initialize tracker for minimum validation loss
valid_loss_min = np.Inf # set initial "min" to infinity

for epoch in range(n_epochs):
    # monitor training loss
    train_loss = 0.0
    valid_loss = 0.0
    model.train() # prep model for training
    for i in range(int(len(trainbw_data))):
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        b=convert_numpy_tensor(trainbw_data[i])
        b=b.cuda()
        compressed = model.encoder(b)
        output=model.decoder(compressed)
        g=convert_numpy_tensor(train_data[i])
        g=g.cuda()
        # calculate the loss
        loss = criterion(output,g.squeeze())
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*b.size(0)
    model.eval() # prep model for evaluation
    for j in range(int(len(testbw_data))):
        # forward pass: compute predicted outputs by passing inputs to the model
        c=torch.from_numpy(testbw_data[j])
        c=c.cuda()
        compressed = model.encoder(c)
        output=model.decoder(compressed)
        h=convert_numpy_tensor(test_data[j])
        h=h.cuda()
        # calculate the loss
        loss = criterion(output,h.squeeze())
        # update running validation loss
        valid_loss += loss.item()*c.size(0)
        if (j==len(test_data)-1) and (epoch==n_epochs):
            plt.plot(testbw_data[j])
            plt.plot(output.detach().numpy())

    # print training/validation statistics
    # calculate average loss over an epoch
    train_loss = train_loss/int(len(trainbw_data))
    valid_loss = valid_loss/int(len(testbw_data))

    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch+1,
        train_loss,
        valid_loss
        ))
# Out:
# Epoch: 1 	Training Loss: 23.805459 	Validation Loss: 24.515624
# Epoch: 2 	Training Loss: 22.897335 	Validation Loss: 23.545647
# Epoch: 3 	Training Loss: 22.593832 	Validation Loss: 22.964614
# Epoch: 4 	Training Loss: 21.945496 	Validation Loss: 21.994977
# Epoch: 5 	Training Loss: 20.593916 	Validation Loss: 21.023735
# Epoch: 6 	Training Loss: 19.338934 	Validation Loss: 20.075363
# Epoch: 7 	Training Loss: 18.287507 	Validation Loss: 19.162529
# Epoch: 8 	Training Loss: 17.384004 	Validation Loss: 18.478591
# Epoch: 9 	Training Loss: 16.672108 	Validation Loss: 17.756082
# Epoch: 10 	Training Loss: 15.996146 	Validation Loss: 17.084912
# Epoch: 11 	Training Loss: 15.325654 	Validation Loss: 16.495428
# Epoch: 12 	Training Loss: 14.696718 	Validation Loss: 15.983780
# Epoch: 13 	Training Loss: 14.116296 	Validation Loss: 15.486438
# Epoch: 14 	Training Loss: 13.597029 	Validation Loss: 15.141400
# Epoch: 15 	Training Loss: 13.180885 	Validation Loss: 14.782237
# Epoch: 16 	Training Loss: 12.770416 	Validation Loss: 14.486169
# Epoch: 17 	Training Loss: 12.418638 	Validation Loss: 14.197931
# Epoch: 18 	Training Loss: 12.050889 	Validation Loss: 13.897709
# Epoch: 19 	Training Loss: 11.706480 	Validation Loss: 13.655162
# Epoch: 20 	Training Loss: 11.436797 	Validation Loss: 13.447099
# Epoch: 21 	Training Loss: 11.207222 	Validation Loss: 13.293992
# Epoch: 22 	Training Loss: 11.014492 	Validation Loss: 13.173889
# Epoch: 23 	Training Loss: 10.784200 	Validation Loss: 12.973443
# Epoch: 24 	Training Loss: 10.543793 	Validation Loss: 12.827751
# Epoch: 25 	Training Loss: 10.323317 	Validation Loss: 12.651901
# Epoch: 26 	Training Loss: 10.166027 	Validation Loss: 12.480853
# Epoch: 27 	Training Loss: 10.020090 	Validation Loss: 12.361902
# Epoch: 28 	Training Loss: 9.866229 	Validation Loss: 12.230390

# %%
#check for viz
c=torch.from_numpy(noise_bw_data[15000])
c=c.cuda()
compressed = model.encoder(c)
output=model.decoder(compressed)
output=output.detach().cpu().numpy()
plt.plot(output , label = 'Denoised')
plt.plot(noise_bw_data[15000] , label = 'Noisy')
plt.plot(data[15000] , label = 'Clean')
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

# %%
#testing
snr_original=0
snr_noise_added=0
snr_denoised=0
rootms=0
for i in range(20000,30000):
  c=torch.from_numpy(noise_bw_data[i])
  c=c.cuda()
  compressed = model.encoder(c)
  output=model.decoder(compressed)
  output=output.detach().cpu().numpy()
  d=data[i]
  snr_original=snr_original+signaltonoise(d,n[i])
  snr_noise_added=snr_noise_added+signaltonoise(noise_bw_data[i],n[i])
  snr_denoised=snr_denoised+signaltonoise(output,output-d)
  rootms=rootms+rmse(d,output)
snr_original=snr_original/10000
snr_noise_added=snr_noise_added/10000
snr_denoised=snr_denoised/10000
rootms=rootms/10000
print('snr of original signal {} db'.format(snr_original))
print('snr of noise_added signal {} db'.format(snr_noise_added))
print('snr of denoised signal {} db'.format(snr_denoised))
print('root mean square error {}'.format(rootms))
# Out:
# snr of original signal -11.536007325399444 db
# snr of noise_added signal 8.115978134833888 db
# snr of denoised signal 15.55871735039537 db
# root mean square error 0.15508947919782962

# %%
#store the saved model
torch.save(model.state_dict(), 'bw.pt')

# %%
from google.colab import files
files.download('bw.pt')

# %%
#loading the model..........
model.load_state_dict(torch.load('bw.pt'))
# Out:
# <All keys matched successfully>

# %%
# Wavelet Transform
import pywt

# Define wavelet function and level of decomposition
wavelet = 'db4'
level = 4

# Denoise each signal using wavelet transform
denoised_data = []
for signal in noise_bw_data:
    # Perform wavelet decomposition
    coeffs = pywt.wavedec(signal, wavelet, level=level)
    # Set threshold for coefficients
    sigma = np.median(np.abs(coeffs[-level])) / 0.6745
    threshold = sigma * np.sqrt(2 * np.log(len(signal)))
    # Apply soft thresholding to coefficients
    denoised_coeffs = [pywt.threshold(c, threshold, mode='soft') for c in coeffs]
    # Reconstruct denoised signal from coefficients
    denoised_signal = pywt.waverec(denoised_coeffs, wavelet)
    denoised_data.append(denoised_signal)

import matplotlib.pyplot as plt

# Plot first signal in database
signal_index = 15000
plt.figure(figsize=(10, 5))
plt.subplot(2, 1, 1)
plt.plot(noise_bw_data[signal_index])
plt.title('Noisy ECG Signal')
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.subplot(2, 1, 2)
plt.plot(denoised_data[signal_index])
plt.title('Denoised Signal using Wavelet Transform')
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.tight_layout()
plt.show()

#testing
snr_original=0
snr_noise_added=0
snr_denoised=0
rootms=0
for i in range(20000,30000):
  output = denoised_data[i]
  d=data[i]
  snr_original=snr_original+signaltonoise(d,n[i])
  snr_noise_added=snr_noise_added+signaltonoise(noise_bw_data[i],n[i])
  snr_denoised=snr_denoised+signaltonoise(output,output-d)
  rootms=rootms+rmse(d,output)
snr_original=snr_original/10000
snr_noise_added=snr_noise_added/10000
snr_denoised=snr_denoised/10000
rootms=rootms/10000
print('snr of original signal {} db'.format(snr_original))
print('snr of noise_added signal {} db'.format(snr_noise_added))
print('snr of denoised signal {} db'.format(snr_denoised))
print('root mean square error {}'.format(rootms))
# Out:
# snr of original signal -11.62018682034503 db
# snr of noise_added signal 8.08746942087524 db
# snr of denoised signal 8.620480064125159 db
# root mean square error 0.5450213476973639

# %%
# Butterworth low-pass filter
import numpy as np
import scipy.signal as signal
import matplotlib.pyplot as plt

# Define Butterworth low-pass filter
cutoff = 0.1  # Cutoff frequency
order = 5  # Filter order
b, a = signal.butter(order, cutoff, btype='low', analog=False)

# Apply filter to each data point in the noisy database
denoised_signal = []
for i in range(len(noise_bw_data)):
  denoised_point = signal.filtfilt(b, a, noise_bw_data[i])
  denoised_signal.append(denoised_point)

# Plot the first data point in the noisy and denoised databases
signal_index = 15000
plt.figure(figsize=(10, 5))
plt.subplot(2, 1, 1)
plt.plot(noise_bw_data[signal_index])
plt.title('Noisy ECG Signal')
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.subplot(2, 1, 2)
plt.plot(denoised_signal[signal_index])
plt.title('Denoised Signal using Butterworth low-pass filter')
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.tight_layout()
plt.show()

#testing
snr_original=0
snr_noise_added=0
snr_denoised=0
rootms=0
for i in range(20000,30000):
  output = denoised_signal[i]
  d=data[i]
  snr_original=snr_original+signaltonoise(d,n[i])
  snr_noise_added=snr_noise_added+signaltonoise(noise_bw_data[i],n[i])
  snr_denoised=snr_denoised+signaltonoise(output,output-d)
  rootms=rootms+rmse(d,output)
snr_original=snr_original/10000
snr_noise_added=snr_noise_added/10000
snr_denoised=snr_denoised/10000
rootms=rootms/10000
print('snr of original signal {} db'.format(snr_original))
print('snr of noise_added signal {} db'.format(snr_noise_added))
print('snr of denoised signal {} db'.format(snr_denoised))
print('root mean square error {}'.format(rootms))
# Out:
# snr of original signal -11.62018682034503 db
# snr of noise_added signal 8.08746942087524 db
# snr of denoised signal 8.029962777362682 db
# root mean square error 0.598600532747396

# %%
# FIR filter
import scipy.signal as signal

# Define filter coefficients
nyquist_freq = 100  # Hz
cutoff_freq =  20 # Hz
numtaps = 101
taps = signal.firwin(numtaps, cutoff_freq/nyquist_freq)

# Apply filter to all signals in noisy dataset
denoised_signals = []
for i in range(len(noise_bw_data)):
    denoised_signal = signal.convolve(noise_bw_data[i], taps, mode='same')
    denoised_signals.append(denoised_signal)

# Plot original and denoised signals for first signal in dataset
signal_index = 15000
plt.figure(figsize=(10, 5))
plt.subplot(2, 1, 1)
plt.plot(noise_bw_data[signal_index])
plt.title('Noisy ECG Signal')
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.subplot(2, 1, 2)
plt.plot(denoised_signals[signal_index])
plt.title('Denoised Signal using FIR filter')
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.tight_layout()
plt.show()

#testing
snr_original=0
snr_noise_added=0
snr_denoised=0
rootms=0
for i in range(20000,30000):
  output = denoised_signals[i]
  d=data[i]
  snr_original=snr_original+signaltonoise(d,n[i])
  snr_noise_added=snr_noise_added+signaltonoise(noise_bw_data[i],n[i])
  snr_denoised=snr_denoised+signaltonoise(output,output-d)
  rootms=rootms+rmse(d,output)
snr_original=snr_original/10000
snr_noise_added=snr_noise_added/10000
snr_denoised=snr_denoised/10000
rootms=rootms/10000
print('snr of original signal {} db'.format(snr_original))
print('snr of noise_added signal {} db'.format(snr_noise_added))
print('snr of denoised signal {} db'.format(snr_denoised))
print('root mean square error {}'.format(rootms))
# Out:
# snr of original signal -11.62018682034503 db
# snr of noise_added signal 8.08746942087524 db
# snr of denoised signal 8.096363860776052 db
# root mean square error 0.5972649427732803

# %%
pip install pyfda
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyfda
#   Downloading pyfda-0.7.1-py3-none-any.whl (597 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 597.6/597.6 KB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: docutils in /usr/local/lib/python3.9/dist-packages (from pyfda) (0.16)
# Collecting pyqt5
#   Downloading PyQt5-5.15.9-cp37-abi3-manylinux_2_17_x86_64.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 82.5 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from pyfda) (1.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from pyfda) (1.22.4)
# Requirement already satisfied: markdown in /usr/local/lib/python3.9/dist-packages (from pyfda) (3.4.1)
# Requirement already satisfied: matplotlib>=2.1 in /usr/local/lib/python3.9/dist-packages (from pyfda) (3.7.1)
# Collecting mplcursors
#   Downloading mplcursors-0.5.2.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.0/89.0 KB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numexpr in /usr/local/lib/python3.9/dist-packages (from pyfda) (2.8.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.1->pyfda) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.1->pyfda) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.1->pyfda) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.1->pyfda) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.1->pyfda) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.1->pyfda) (8.4.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.1->pyfda) (5.12.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.1->pyfda) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.1->pyfda) (4.39.2)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown->pyfda) (6.1.0)
# Collecting PyQt5-sip<13,>=12.11
#   Downloading PyQt5_sip-12.11.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (357 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.8/357.8 KB 29.3 MB/s eta 0:00:00
# Collecting PyQt5-Qt5>=5.15.2
#   Downloading PyQt5_Qt5-5.15.2-py3-none-manylinux2014_x86_64.whl (59.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown->pyfda) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1->pyfda) (1.16.0)
# Building wheels for collected packages: mplcursors
#   Building wheel for mplcursors (setup.py) ... done
#   Created wheel for mplcursors: filename=mplcursors-0.5.2-py3-none-any.whl size=21071 sha256=1e009c021e8c1e9e4825061c4e4ffdbf269d0d6cb9478e04703cb2b751f3cc5f
#   Stored in directory: /root/.cache/pip/wheels/b1/98/ff/4885c231adf3d185efdc38cf8aa2527f1b255ca714a43cb125
# Successfully built mplcursors
# Installing collected packages: PyQt5-Qt5, PyQt5-sip, pyqt5, mplcursors, pyfda
# Successfully installed PyQt5-Qt5-5.15.2 PyQt5-sip-12.11.1 mplcursors-0.5.2 pyfda-0.7.1 pyqt5-5.15.9

# %%
# Median filter
from scipy.signal import medfilt

# Define the window size of the median filter
window_size = 5

# Initialize list to store denoised signals
denoised_signals = []

# Apply median filter to all signals in noisy dataset
for i in range(len(noise_bw_data)):
    x = noise_bw_data[i]
    y = medfilt(x, kernel_size=window_size)
    denoised_signals.append(y)

# Plot original and denoised signals for first signal in dataset
signal_index = 15000
plt.figure(figsize=(10, 5))
plt.subplot(2, 1, 1)
plt.plot(noise_bw_data[signal_index])
plt.title('Noisy ECG Signal')
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.subplot(2, 1, 2)
plt.plot(denoised_signals[signal_index])
plt.title('Denoised Signal using Median filter')
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.tight_layout()
plt.show()

#testing
snr_original=0
snr_noise_added=0
snr_denoised=0
rootms=0
for i in range(20000,30000):
  output = denoised_signals[i]
  d=data[i]
  snr_original=snr_original+signaltonoise(d,n[i])
  snr_noise_added=snr_noise_added+signaltonoise(noise_bw_data[i],n[i])
  snr_denoised=snr_denoised+signaltonoise(output,output-d)
  rootms=rootms+rmse(d,output)
snr_original=snr_original/10000
snr_noise_added=snr_noise_added/10000
snr_denoised=snr_denoised/10000
rootms=rootms/10000
print('snr of original signal {} db'.format(snr_original))
print('snr of noise_added signal {} db'.format(snr_noise_added))
print('snr of denoised signal {} db'.format(snr_denoised))
print('root mean square error {}'.format(rootms))
# Out:
# snr of original signal -11.62018682034503 db
# snr of noise_added signal 8.08746942087524 db
# snr of denoised signal 8.088622066868144 db
# root mean square error 0.5976984568941721
